# %% [markdown]
# # Credit-Card-Fraud-Detection

# %% [markdown]
# # Information
# This project is based on an investigation to detect number of fraud transations as compared to normal or valid transations so that the bank companies can improve the payment transcation platform.
# Here we have use a small static data set from Kaggle
# # Importing all necessary libaries

# %%
#importing
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading dataset
data=pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
#finding for fraud==1 && normal==0 ,then differentating it up.
fraud=data.loc[data['Class']==1]
normal=data.loc[data['Class']==0]

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 541    -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623     0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 541     0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623    -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108   -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329   -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
# ...          ...       ...       ...       ...       ...     ...    ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
fraud.sum()
# Out:
# Time      3.972743e+07
# V1       -2.347799e+03
# V2        1.782899e+03
# V3       -3.460374e+03
# V4        2.234678e+03
# V5       -1.550403e+03
# V6       -6.876865e+02
# V7       -2.739816e+03
# V8        2.807529e+02
# V9       -1.269912e+03
# V10      -2.793026e+03
# V11       1.869685e+03
# V12      -3.079621e+03
# V13      -5.379224e+01
# V14      -3.430088e+03
# V15      -4.572094e+01
# V16      -2.036853e+03
# V17      -3.279592e+03
# V18      -1.105184e+03
# V19       3.348844e+02
# V20       1.831811e+02
# V21       3.510855e+02
# V22       6.912050e+00
# V23      -1.983152e+01
# V24      -5.172411e+01
# V25       2.039285e+01
# V26       2.541088e+01
# V27       8.392280e+01
# V28       3.722831e+01
# Amount    6.012797e+04
# Class     4.920000e+02
# dtype: float64

# %%
len(fraud)
# Out:
# 492

# %%
len(normal)
# Out:
# 284315

# %%
normal
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284315 rows x 31 columns]

# %%
sns.relplot(x='Amount',y='Time',hue='Class', data=data)

# %%
data1= data.sample(frac=0.1, random_state = 1)
print(data1.shape)
print(data1.describe())
# Out:
# (28481, 31)
#                 Time            V1            V2            V3            V4  \
# count   28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean    94705.035216     -0.001143     -0.018290      0.000795      0.000350
# std     47584.727034      1.994661      1.709050      1.522313      1.420003
# min         0.000000    -40.470142    -63.344698    -31.813586     -5.266509
# 25%     53924.000000     -0.908809     -0.610322     -0.892884     -0.847370
# 50%     84551.000000      0.031139      0.051775      0.178943     -0.017692
# 75%    139392.000000      1.320048      0.792685      1.035197      0.737312
# max    172784.000000      2.411499     17.418649      4.069865     16.715537
#
#                  V5            V6            V7            V8            V9  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.015666      0.003634     -0.008523     -0.003040      0.014536
# std        1.395552      1.334985      1.237249      1.204102      1.098006
# min      -42.147898    -19.996349    -22.291962    -33.785407     -8.739670
# 25%       -0.703986     -0.765807     -0.562033     -0.208445     -0.632488
# 50%       -0.068037     -0.269071      0.028378      0.024696     -0.037100
# 75%        0.603574      0.398839      0.559428      0.326057      0.621093
# max       28.762671     22.529298     36.677268     19.587773      8.141560
#
#        ...           V21           V22           V23           V24  \
# count  ...  28481.000000  28481.000000  28481.000000  28481.000000
# mean   ...      0.004740      0.006719     -0.000494     -0.002626
# std    ...      0.744743      0.728209      0.645945      0.603968
# min    ...    -16.640785    -10.933144    -30.269720     -2.752263
# 25%    ...     -0.224842     -0.535877     -0.163047     -0.360582
# 50%    ...     -0.029075      0.014337     -0.012678      0.038383
# 75%    ...      0.189068      0.533936      0.148065      0.434851
# max    ...     22.588989      6.090514     15.626067      3.944520
#
#                 V25           V26           V27           V28        Amount  \
# count  28481.000000  28481.000000  28481.000000  28481.000000  28481.000000
# mean      -0.000917      0.004762     -0.001689     -0.004154     89.957884
# std        0.520679      0.488171      0.418304      0.321646    270.894630
# min       -7.025783     -2.534330     -8.260909     -9.617915      0.000000
# 25%       -0.319611     -0.328476     -0.071712     -0.053379      5.980000
# 50%        0.015231     -0.049750      0.000914      0.010753     22.350000
# 75%        0.351466      0.253580      0.090329      0.076267     78.930000
# max        5.541598      3.118588     11.135740     15.373170  19656.530000
#
#               Class
# count  28481.000000
# mean       0.001720
# std        0.041443
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
# Plot histograms of each parameter 
data.hist(figsize = (20,20))
plt.show()

# %%
#Plotting the dataset
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x213404a9670>,
#  <matplotlib.lines.Line2D at 0x21340512970>,
#  <matplotlib.lines.Line2D at 0x21340512a90>,
#  <matplotlib.lines.Line2D at 0x213404f4790>,
#  <matplotlib.lines.Line2D at 0x213404f47c0>,
#  <matplotlib.lines.Line2D at 0x21340512cd0>,
#  <matplotlib.lines.Line2D at 0x21340512df0>,
#  <matplotlib.lines.Line2D at 0x21340512f10>,
#  <matplotlib.lines.Line2D at 0x2134051f070>,
#  <matplotlib.lines.Line2D at 0x2134051f190>,
#  <matplotlib.lines.Line2D at 0x213404a94c0>,
#  <matplotlib.lines.Line2D at 0x2134051f2b0>,
#  <matplotlib.lines.Line2D at 0x2134051f4c0>,
#  <matplotlib.lines.Line2D at 0x2134051f5e0>,
#  <matplotlib.lines.Line2D at 0x2134051f700>,
#  <matplotlib.lines.Line2D at 0x2134051f820>,
#  <matplotlib.lines.Line2D at 0x2134051f940>,
#  <matplotlib.lines.Line2D at 0x2134051fa60>,
#  <matplotlib.lines.Line2D at 0x2134051fb80>,
#  <matplotlib.lines.Line2D at 0x2134051fca0>,
#  <matplotlib.lines.Line2D at 0x2134051fdc0>,
#  <matplotlib.lines.Line2D at 0x2134051fee0>,
#  <matplotlib.lines.Line2D at 0x21340524040>,
#  <matplotlib.lines.Line2D at 0x21340524160>,
#  <matplotlib.lines.Line2D at 0x21340524280>,
#  <matplotlib.lines.Line2D at 0x213405243a0>,
#  <matplotlib.lines.Line2D at 0x213405244c0>,
#  <matplotlib.lines.Line2D at 0x213405245e0>,
#  <matplotlib.lines.Line2D at 0x21340524700>,
#  <matplotlib.lines.Line2D at 0x21340524820>,
#  <matplotlib.lines.Line2D at 0x21340524940>]

# %% [markdown]
# # Using Logistic Regressing

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X=data.iloc[:,:-1]
Y=data['Class']

# %%
X_train,X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.33)

# %%
clf= linear_model.LogisticRegression(C=1e5)

# %%
clf.fit(X_train, Y_train)
# Out:
# C:\Users\Rishav\anaconda3\envs\Tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=100000.0)

# %%
#making model
y_pred=np.array(clf.predict(X_test))
y=np.array(Y_test)

# %%
from sklearn.metrics import confusion_matrix , classification_report ,accuracy_score

# %%
print(confusion_matrix(Y_test,y_pred))
# Out:
# [[93809    28]
#  [   57    93]]

# %%
print(accuracy_score(Y_test,y_pred))
# Out:
# 0.9990956196069669

# %%
#printing report 
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93837
#            1       0.77      0.62      0.69       150
#
#     accuracy                           1.00     93987
#    macro avg       0.88      0.81      0.84     93987
# weighted avg       1.00      1.00      1.00     93987

# %% [markdown]
# # predict report

# %%
print(confusion_matrix(y,y_pred))
# Out:
# [[93809    28]
#  [   57    93]]

# %%
print(accuracy_score(y,y_pred))
# Out:
# 0.9990956196069669

# %%
#printing report 
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93837
#            1       0.77      0.62      0.69       150
#
#     accuracy                           1.00     93987
#    macro avg       0.88      0.81      0.84     93987
# weighted avg       1.00      1.00      1.00     93987
